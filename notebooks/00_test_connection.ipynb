# %%
import sys
import os
# adiciona a raiz do projeto no caminho de import
sys.path.append(os.path.abspath(".."))

print("OK: project root added ->", os.path.abspath(".."))
# Out:
# OK: project root added -> c:\Users\MAX\.vscode\python_coursera

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\MAX\.vscode\python_coursera\.venv\Scripts\python.exe

# %%
import os
import sys

print("Python executable:", sys.executable)
print("Current working dir:", os.getcwd())
print("Files in current dir:", os.listdir(".")[:10])
# Out:
# Python executable: c:\Users\MAX\.vscode\python_coursera\.venv\Scripts\python.exe
# Current working dir: c:\Users\MAX\.vscode\python_coursera\notebooks
# Files in current dir: ['00_test_connection.ipynb']

# %%
import pandas as pd
import numpy as np

import sqlalchemy
import psycopg2
from dotenv import load_dotenv

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("sqlalchemy:", sqlalchemy.__version__)
print("psycopg2:", psycopg2.__version__)
print("dotenv: ok")
# Out:
# pandas: 2.3.3
# numpy: 2.4.1
# sqlalchemy: 2.0.45
# psycopg2: 2.9.11 (dt dec pq3 ext lo64)
# dotenv: ok

# %%
from dotenv import load_dotenv
import os

# carrega explicitamente o .env da raiz do projeto
env_path = os.path.abspath(os.path.join("..", ".env"))
load_dotenv(env_path)

print("Loaded .env from:", env_path)

vars_to_check = ["DB_HOST", "DB_PORT", "DB_NAME", "DB_USER", "DB_PASSWORD"]
for v in vars_to_check:
    print(v, "->", "OK" if os.getenv(v) else "MISSING")
# Out:
# Loaded .env from: c:\Users\MAX\.vscode\python_coursera\.env
# DB_HOST -> OK
# DB_PORT -> OK
# DB_NAME -> OK
# DB_USER -> OK
# DB_PASSWORD -> OK
